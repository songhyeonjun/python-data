# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from glob import glob

# %%
import pathlib

# %%
data_dir = os.chdir(os.getcwd() + "/../../travel_images2")

# %%
image_count = len(list(glob('*/*.*')))
print(image_count)
# Out:
# 35093

# %%
travel = glob('travel and  adventure/*')
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1F3DA09B448>

# %%
batch_size = 32
img_height = 150
img_width = 150

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-74c9d0fc07a0> in <module>
#       1 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
# ----> 2   pathlib.Path(data_dir),
#       3   validation_split=0.2,
#       4   subset="training",
#       5   seed=123,
#
# C:\ProgramData\Anaconda3\lib\pathlib.py in __new__(cls, *args, **kwargs)
#    1008         if cls is Path:
#    1009             cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1010         self = cls._from_parts(args, init=False)
#    1011         if not self._flavour.is_supported:
#    1012             raise NotImplementedError("cannot instantiate %r on your system"
#
# C:\ProgramData\Anaconda3\lib\pathlib.py in _from_parts(cls, args, init)
#     663         # right flavour.
#     664         self = object.__new__(cls)
# --> 665         drv, root, parts = self._parse_args(args)
#     666         self._drv = drv
#     667         self._root = root
#
# C:\ProgramData\Anaconda3\lib\pathlib.py in _parse_args(cls, args)
#     647                 parts += a._parts
#     648             else:
# --> 649                 a = os.fspath(a)
#     650                 if isinstance(a, str):
#     651                     # Force-cast str subclasses to str (issue #21127)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
