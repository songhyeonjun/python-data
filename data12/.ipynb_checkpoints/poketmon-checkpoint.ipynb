# %%
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/pok/Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.drop(columns=['#', 'Type 1', 'Type 2', 'Generation'], inplace=True)

# %%
df2 = df.set_index('Name')

# %%
df2.head()
# Out:
#                        Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur                318  45      49       49       65       65     45
# Ivysaur                  405  60      62       63       80       80     60
# Venusaur                 525  80      82       83      100      100     80
# VenusaurMega Venusaur    625  80     100      123      122      120     80
# Charmander               309  39      52       43       60       50     65
#
#                        Legendary
# Name
# Bulbasaur                  False
# Ivysaur                    False
# Venusaur                   False
# VenusaurMega Venusaur      False
# Charmander                 False

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 8 columns):
# Total        800 non-null int64
# HP           800 non-null int64
# Attack       800 non-null int64
# Defense      800 non-null int64
# Sp. Atk      800 non-null int64
# Sp. Def      800 non-null int64
# Speed        800 non-null int64
# Legendary    800 non-null bool
# dtypes: bool(1), int64(7)
# memory usage: 50.8+ KB

# %%
data = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
X_train, X_test, y_train, y_test = train_test_split(
    df[data], # 문제
    df['Legendary'], # 정답
    test_size = 0.2, # test-size비율
    random_state = 150 # 시드값 설정
)

# %%
df_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
svc_clf = SVC()
clf_list = [df_clf, rf_clf, svc_clf]

# %%
for clf in clf_list:
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    print(format(accuracy_score(y_test, pred)))
# Out:
# 0.9625
# 0.96875
# 0.93125

# %%
kfold = KFold(n_splits=5)

# %%
def exec_kfold(clf, k):
    acc_list = []
    kfold = KFold(n_splits=k)
    for i, (train_index, test_index) in enumerate(kfold.split(df[data])):
        X_train2, X_test2 = df[data].values[train_index], df[data].values[test_index]
        y_train2, y_test2 = df['Legendary'].values[train_index], df['Legendary'].values[test_index]
        
        clf.fit(X_train2, y_train2)
        pred2 = clf.predict(X_test2)
        acc = accuracy_score(y_test2, pred2)
        acc_list.append(acc)
        print(i, ': 정확도>> {0:.2f}'.format(acc))
    print('평균 정확도>> {0:.2f}'.format(np.mean(acc_list)))
    return np.mean(acc_list)

# %%
exec_kfold(df_clf, 10)
# Out:
# 0 : 정확도>> 0.97
# 1 : 정확도>> 0.97
# 2 : 정확도>> 0.99
# 3 : 정확도>> 0.94
# 4 : 정확도>> 0.99
# 5 : 정확도>> 0.86
# 6 : 정확도>> 0.88
# 7 : 정확도>> 1.00
# 8 : 정확도>> 0.93
# 9 : 정확도>> 0.95
# 평균 정확도>> 0.95
# 0.9475

# %%
acc_total = []
model_list = ['decision tree', 'random forest', 'svm']
for i, clf in enumerate(clf_list):
    print(model_list[i], '----검증시작----')
    acc_result = exec_kfold(clf, 5)
    acc_total.append(acc_result)
# Out:
# decision tree ----검증시작----
# 0 : 정확도>> 0.97
# 1 : 정확도>> 0.96
# 2 : 정확도>> 0.93
# 3 : 정확도>> 0.94
# 4 : 정확도>> 0.93
# 평균 정확도>> 0.95
# random forest ----검증시작----
# 0 : 정확도>> 0.97
# 1 : 정확도>> 0.94
# 2 : 정확도>> 0.94
# 3 : 정확도>> 0.96
# 4 : 정확도>> 0.89
# 평균 정확도>> 0.94
# svm ----검증시작----
# 0 : 정확도>> 0.98
# 1 : 정확도>> 0.94
# 2 : 정확도>> 0.89
# 3 : 정확도>> 0.91
# 4 : 정확도>> 0.86
# 평균 정확도>> 0.92

# %%
acc_result
# Out:
# 0.91625

# %%
for i in range(3):
    print(model_list[i], " 교차검증 평균: ", acc_total[i])
# Out:
# decision tree  교차검증 평균:  0.9475
# random forest  교차검증 평균:  0.94625
# svm  교차검증 평균:  0.91625

# %%
# 최대 평균값 ==
max_value = np.max(acc_total)
# 최대 평균값 인덱스 ==
max_index = np.argmax(acc_total)
# 최대 평균값 모델명 ==
max_model = model_list[max_index]

print('최고 교차 검증 평균>> ', max_value)
print('최고 교차 검증 인덱스>> ', max_index)
print('최고 교차 검증 모델링>> ', max_model)
# Out:
# 최고 교차 검증 평균>>  0.9475
# 최고 교차 검증 인덱스>>  0
# 최고 교차 검증 모델링>>  decision tree

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Library/Fonts/AppleGothic.ttf"
f_path = "../Jalnan.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
legend = df2.Legendary

# %%
df2.head()
# Out:
#                        Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur                318  45      49       49       65       65     45
# Ivysaur                  405  60      62       63       80       80     60
# Venusaur                 525  80      82       83      100      100     80
# VenusaurMega Venusaur    625  80     100      123      122      120     80
# Charmander               309  39      52       43       60       50     65
#
#                        Legendary
# Name
# Bulbasaur                  False
# Ivysaur                    False
# Venusaur                   False
# VenusaurMega Venusaur      False
# Charmander                 False

# %% [markdown]
# 전설의 포켓몬 Total 정렬

# %%
df2[legend]['Total'].sort_values().plot(kind='barh', 
                                        rot=10,figsize=(20,50),
                                        grid=True
                                       )
plt.show()

# %%
df2['Total'].groupby(df2['Legendary']).mean()
# Out:
# Legendary
# False    417.213605
# True     637.384615
# Name: Total, dtype: float64

# %%
일반 포켓몬, 전설 포켓몬 Total평균

# %%
df2['Total'].groupby(df2['Legendary']).mean().plot(kind='bar', 
                                                   rot=5,
                                                   title="Total평균",
                                                   colors=['red', 'blue']
                                                  )
plt.show()

# %% [markdown]
# decision tree, random forest, svm 평균 정확도

# %%
total_df = pd.DataFrame(data=acc_total, columns=['평균 정확도'], index=['decision tree', 'random forest', 'svm'])
total_df

# %%
plt.figure()
total_df['평균 정확도'].plot(grid=True, marker='*')
plt.ylim([0.9, 1])     # Y축의 범위: [ymin, ymax]
plt.show()
